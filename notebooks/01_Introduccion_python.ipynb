# %% [markdown]
# # Introducción a Python

# %% [markdown]
# ## Variables
# * que es una variable
# * estandar para nombrar variables

# %%
# este es un comentario
# Estandar PEP8
temperatura = 1
temperatura_sala = 20 #snake_case
temperatura_sala
# Out:
# 20

# %% [markdown]
# ## Tipos de datos
# * Numéricos
# * De texto
# * Booleanos
# * De secuencias
# * De mapeo
# * Conjuntos
# * De bytes
#
# https://blog.hubspot.es/website/tipos-de-datos-python

# %%
# numericos
3+2j,1,1.2
# Out:
# ((3+2j), 1, 1.2)

# %%
# texto str
variable_texto="este es un texto"
variable_texto2 = """Esto es un texto
y esto es otro texto dentro del mismo"""
variable_texto2
# Out:
# 'Esto es un texto\ny esto es otro texto dentro del mismo'

# %%
# booleanos
variable_booleana = True
variable_booleana
# Out:
# 1

# %%
# listas
variable_lista = [1,2,3,4,5,6,"hola",True]
variable_lista[2]="modificado"
variable_lista
# Out:
# [1, 2, 'modificado', 4, 5, 6, 'hola', True]

# %%
# tuplas
tupla = (1,2,3,4,5,6)
tupla[2] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9236be03c9e3> in <cell line: 3>()
#       1 # tuplas
#       2 tupla = (1,2,3,4,5,6)
# ----> 3 tupla[2] = 0
#
# TypeError: 'tuple' object does not support item assignment

# %%
range(0,10,2)
# Out:
# range(0, 10, 2)

# %%
# diccionarios
mi_diccionario = {
    'nombre':"juan",
    "edad":22,
    "profesional":True

 }

mi_diccionario['edad']=30
mi_diccionario
# Out:
# {'nombre': 'juan', 'edad': 30, 'profesional': True}

# %% [markdown]
# ## Operadores
# * Operadores aritméticos
# * Operadores relacionales
# * Operadores Bit a Bit
# * Operadores de asignación
# * Operadores lógicos
# * Operadores de pertenencia
# * Operadores de identidad
#
# https://www.freecodecamp.org/espanol/news/operadores-basicos-en-python-con-ejemplos/

# %%
nueva_variable = 2**3
nueva_variable
# Out:
# 8

# %%
# operadores de asignación
variable = 1

variable += 10

variable
# Out:
# 11

# %%
variable = 1

variable -= 10

variable
# Out:
# -9

# %%
variable = 1

variable *= 10

variable
# Out:
# 10

# %% [markdown]
# ## Como imprimir mensajes por consola

# %%
print("Este es un mensaje")
a = 1+2
b = a+8
print("El resultado es:",b)
# Out:
# Este es un mensaje
# El resultado es: 11

# %% [markdown]
# ## Ejemplos de práctica
# * realiza un algoritmo que pueda calcular el area de un rectangulo
# * Calcula la ecuación de una recta dado dos puntos

# %%
base = 10
altura = 7

area = base*altura

print("el area es:",area)
print(f"el area es {area+1} mts**2")
# Out:
# el area es: 70
# el area es 71 mts**2

# %%
coord_x1,coord_y1 = 1,5
coord_x2,coord_y2 = 3,10

pendiente = (coord_y2-coord_y1)/(coord_x2-coord_x1)
print(pendiente)
# Out:
# 2.5

# %% [markdown]
# y-y1=m(x-x1)
#
# y=m(x-x1)+y1
#
# y=mx-mx1+y1
#
# b= -mx1+y1

# %%
intercepto = -pendiente*coord_x1+coord_y1
print(intercepto)
# Out:
# 2.5

# %%
print(f"la formula de la recta es y={pendiente}x+{intercepto}")
# Out:
# la formula de la recta es y=2.5x+2.5
